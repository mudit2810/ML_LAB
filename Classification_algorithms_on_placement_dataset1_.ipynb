# %% [markdown]
# <a href="https://colab.research.google.com/github/mudit2810/ML_LAB/blob/main/Classification_algorithms_on_placement_dataset1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets, linear_model, metrics
import csv 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
dataset = pd.read_csv('/content/drive/MyDrive/Placement_Data_Full_Class (1).csv')  
dataset=np.array(dataset)
In [15]:
from google.colab import drive
drive.mount('/content/drive')
Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
In [16]:
from sklearn import datasets
dataset = datasets.load_iris()
features=dataset.data
label=dataset.target
In [17]:
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(features,label,test_size=0.5)
In [18]:
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

#K-NEAREST NEIGHBORS(KNN)
#from sklearn.neighbors import KNeighborsClassifier
#model=KNeighborsClassifier()

#NAIVE BAYES
#from sklearn.naive_bayes import GaussianNB
#model=GaussianNB()

model.fit(X_train,Y_train)
y_ans=model.predict(X_test)

model.score(X_test,Y_test)
Out[18]:
0.96
In [19]:
#LOGISTIC REGRESSION
#from sklearn.linear_model import LogisticRegression
#model=LogisticRegression()

#K-NEAREST NEIGHBORS(KNN)
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

#NAIVE BAYES
#from sklearn.naive_bayes import GaussianNB
#model=GaussianNB()

model.fit(X_train,Y_train)
y_ans=model.predict(X_test)

model.score(X_test,Y_test)
Out[19]:
0.9466666666666667
In [20]:
#LOGISTIC REGRESSION
#from sklearn.linear_model import LogisticRegression
#model=LogisticRegression()

#K-NEAREST NEIGHBORS(KNN)
#from sklearn.neighbors import KNeighborsClassifier
#model=KNeighborsClassifier()

#NAIVE BAYES
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

model.fit(X_train,Y_train)
y_ans=model.predict(X_test)

model.score(X_test,Y_test)
